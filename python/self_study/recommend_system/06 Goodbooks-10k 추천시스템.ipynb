# %%
import numpy as np
import pandas as pd
import plotnine
from plotnine import *
import os, sys, gc
from tqdm.notebook import tqdm

# %%
books = pd.read_csv('C:/Users/sbpark/books.csv')
book_tags = pd.read_csv('C:/Users/sbpark/book_tags.csv')
ratings = pd.read_csv('C:/Users/sbpark/ratings.csv')
tags = pd.read_csv('C:/Users/sbpark/tags.csv')
to_read = pd.read_csv('C:/Users/sbpark/to_read.csv')

# %% [markdown]
# ## 데이터 확인

# %% [markdown]
# ### books 확인

# %%
books.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# 1  Harry Potter and the Philosopher's Stone  ...       4602479
# 2                                  Twilight  ...       3866839
# 3                     To Kill a Mockingbird  ...       3198671
# 4                          The Great Gatsby  ...       2683664
#
#   work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0            4942365                   155254      66715     127936
# 1            4800065                    75867      75504     101676
# 2            3916824                    95009     456191     436802
# 3            3340896                    72586      60427     117415
# 4            2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 23 columns]

# %%
books.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %%
# 책 추천 시 표지가 영향을 줄 수 있으므로, 이미지를 통한 유사도를 계산할 수 있다.
books['small_image_url'].values[0]
# Out:
# 'https://images.gr-assets.com/books/1447303603s/2767052.jpg'

# %%
#필요한 변수들만 사용

books = books[['book_id','authors','title','ratings_count','average_rating','language_code']].reset_index(drop = True)

# %%
agg = books.groupby('authors')['authors'].agg({'count'})

#plotnine = R의 ggplot
(ggplot(data = agg)
 + geom_histogram(aes(x = 'count'), binwidth = 1, fill = '#49bdb7')
 + labs(title = "Number of the Author's Book",
        x = 'Book Count',
        y = 'Author Count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'black'),
         figure_size = (10,6))

)
# Out:
# <ggplot: (125416491487)>

# %%
print("책의 숫자 : ",books['book_id'].nunique() )
print("저자의 숫자 : ",books['authors'].nunique(), "\n" )
print(pd.DataFrame(agg['count'].describe()).T)
# Out:
# 책의 숫자 :  10000
# 저자의 숫자 :  4664
#
#         count      mean       std  min  25%  50%  75%   max
# count  4664.0  2.144082  3.414442  1.0  1.0  1.0  2.0  60.0

# %%
agg.sort_values(by='count', ascending = False)
# Out:
#                                    count
# authors
# Stephen King                          60
# Nora Roberts                          59
# Dean Koontz                           47
# Terry Pratchett                       42
# Agatha Christie                       39
# ...                                  ...
# Claire North                           1
# Jostein Gaarder, James Anderson        1
# Jostein Gaarder, Paulette Møller       1
# Jostein Gaarder, Sarah Jane Hails      1
# A. Manette Ansay                       1
#
# [4664 rows x 1 columns]

# %%
# 책의 평균 평점 확인
(ggplot(data = books)
 + geom_histogram(aes(x = 'average_rating'), binwidth = 0.1, fill = '#49bdb7')
 + labs(title = "average_rating of the Books",
        x = 'average_ratingt',
        y = 'Book Count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (10,6))

)
# Out:
# <ggplot: (125417258710)>

# %%
# 평점이 3점 이하인 낮은 평점의 책들 > 추천 가치가 있는가?
books[books['average_rating'] <= 3].shape[0]
# Out:
# 14

# %%
books[books['average_rating'] <= 3]
# Out:
#        book_id                         authors  \
# 1408   3320520                   Chetan Bhagat
# 1792    105578                   Chetan Bhagat
# 3549    783291                    Alice Sebold
# 4008      6613                Candace Bushnell
# 4281   4601396                 Chuck Palahniuk
# 4282  16130307               Lauren Weisberger
# 4613      3648                   Claire Messud
# 7449   5557442                      يوسف زيدان
# 8006   8664368                 Howard Jacobson
# 8165  23503361                  Julia Pierpont
# 8873   6855294                 Chuck Palahniuk
# 8959  12878667                     Mark Haddon
# 9020     24929  Gregory Maguire, Douglas Smith
# 9522  19523454                 Chuck Palahniuk
#
#                                                   title  ratings_count  \
# 1408                          The 3 Mistakes of My Life          53331
# 1792                       One Night at the Call Center          40718
# 3549                                    The Almost Moon          28299
# 4008                                       Four Blondes          22278
# 4281                                              Pygmy          21242
# 4282  Revenge Wears Prada: The Devil Returns (The De...          19210
# 4613                             The Emperor's Children          15362
# 7449                                          ظل الأفعى           8299
# 8006                               The Finkler Question           9627
# 8165                      Among the Ten Thousand Things           8458
# 8873                                           Tell-All           9733
# 8959                                      The Red House          10621
# 9020                                               Lost          12534
# 9522                                      Beautiful You           8507
#
#       average_rating language_code
# 1408            2.97           eng
# 1792            2.47           eng
# 3549            2.67           eng
# 4008            2.80           NaN
# 4281            2.96           eng
# 4282            2.84         en-US
# 4613            2.93           NaN
# 7449            3.00           ara
# 8006            2.76           eng
# 8165            2.84           eng
# 8873            2.84           NaN
# 8959            2.93           eng
# 9020            2.80           eng
# 9522            2.98           eng

# %%
# 평점이 높은 순 > 하지만 평점이 높다고 무조건 좋은 책인가? 모수가 적은 것은 아닌가?
books.sort_values(by='average_rating', ascending = False).head()
# Out:
#        book_id                                     authors  \
# 3627     24812                              Bill Watterson
# 3274         8                 J.K. Rowling, Mary GrandPré
# 861   17332218                           Brandon Sanderson
# 8853     95602                             Francine Rivers
# 7946   5031805  Anonymous, Lane T. Dennis, Wayne A. Grudem
#
#                                                   title  ratings_count  \
# 3627                     The Complete Calvin and Hobbes          28900
# 3274  Harry Potter Boxed Set, Books 1-5 (Harry Potte...          33220
# 861      Words of Radiance (The Stormlight Archive, #2)          73572
# 8853                           Mark of the Lion Trilogy           9081
# 7946                                    ESV Study Bible           8953
#
#       average_rating language_code
# 3627            4.82           eng
# 3274            4.77           eng
# 861             4.77           eng
# 8853            4.76         en-US
# 7946            4.76           eng

# %%
# 책의 별점 갯수 확인
(ggplot(data = books)
 + geom_histogram(aes(x = 'ratings_count'), binwidth = 10000, fill = '#49bdb7')
 + labs(title = "ratings_count of the Books",
        x = 'ratings_count',
        y = 'Book Count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (10,6))

)
# Out:
# <ggplot: (125416870349)>

# %%
pd.DataFrame(books['ratings_count'].describe()).T
# Out:
#                  count        mean            std     min       25%      50%  \
# ratings_count  10000.0  54001.2351  157369.956436  2716.0  13568.75  21155.5
#
#                    75%        max
# ratings_count  41053.5  4780653.0

# %%
# 책의 별점 갯수 확인
(ggplot(data = books[books['ratings_count'] < 1000000])
 + geom_histogram(aes(x = 'ratings_count'), binwidth = 10000, fill = '#49bdb7')
 + labs(title = "ratings_count of the Books",
        x = 'ratings_count',
        y = 'Book Count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (10,6))

)
# Out:
# <ggplot: (125416866850)>

# %%
books.sort_values(by='ratings_count', ascending = False).head()
# Out:
#    book_id                      authors  \
# 0  2767052              Suzanne Collins
# 1        3  J.K. Rowling, Mary GrandPré
# 2    41865              Stephenie Meyer
# 3     2657                   Harper Lee
# 4     4671          F. Scott Fitzgerald
#
#                                                title  ratings_count  \
# 0            The Hunger Games (The Hunger Games, #1)        4780653
# 1  Harry Potter and the Sorcerer's Stone (Harry P...        4602479
# 2                            Twilight (Twilight, #1)        3866839
# 3                              To Kill a Mockingbird        3198671
# 4                                   The Great Gatsby        2683664
#
#    average_rating language_code
# 0            4.34           eng
# 1            4.44           eng
# 2            3.57         en-US
# 3            4.25           eng
# 4            3.89           eng

# %%
agg = pd.DataFrame(books['language_code'].value_counts()).reset_index()
agg.columns = ['language_code', 'count']

# %%
# 책의 언어 코드 확인
(ggplot(data = books)
 + geom_histogram(aes(x = 'language_code'), fill = '#49bdb7')
 + labs(title = "language_code of the Books",
        x = 'language_code',
        y = 'Book Count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (12,6))

)
# Out:
# C:\Users\sbpark\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:95: PlotnineWarning: 'stat_bin()' using 'bins = 100'. Pick better value with 'binwidth'.
# <ggplot: (125416890832)>

# %%
books['language_code'].unique()
# Out:
# array(['eng', 'en-US', 'en-CA', nan, 'spa', 'en-GB', 'fre', 'nl', 'ara',
#        'por', 'ger', 'nor', 'jpn', 'en', 'vie', 'ind', 'pol', 'tur',
#        'dan', 'fil', 'ita', 'per', 'swe', 'rum', 'mul', 'rus'],
#       dtype=object)

# %%
# 언어코드 null 값 갯수 확인
books.isnull().sum()
# Out:
# book_id              0
# authors              0
# title                0
# ratings_count        0
# average_rating       0
# language_code     1084
# dtype: int64

# %%
ratings
# Out:
#         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [981756 rows x 3 columns]

# %%
# 사용자가 평점을 매긴 책이 메타데이터에 얼마나 있는가?
# set difference : 차집합계산 (ratings에는 있지만, books에는 없는 책의 id수를 계산)
# 평점을 부여했으나 메타데이터에 있는 책은 812건 뿐이라 contents 기반의 추천 시스템은 성능이 낮을 것으로 예상된다.
len(set(ratings['book_id'].unique()).difference(set(books['book_id'].unique())))
# Out:
# 9188

# %% [markdown]
# ### book의 tag 정보 확인

# %%
book_tags.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
book_tags = pd.merge(tags, book_tags, how = 'left', on = 'tag_id')
book_tags
# Out:
#         tag_id    tag_name  goodreads_book_id  count
# 0            0           -                665      3
# 1            0           -              81176      5
# 2            0           -             147074      2
# 3            0           -            2983489      3
# 4            0           -            6713071      4
# ...        ...         ...                ...    ...
# 999907   34248   Ｆａｖｏｒｉｔｅｓ            8520610    374
# 999908   34248   Ｆａｖｏｒｉｔｅｓ            9361589   3765
# 999909   34249       Ｍａｎｇａ             248871    222
# 999910   34250      ＳＥＲＩＥＳ              28866     24
# 999911   34251  ｆａｖｏｕｒｉｔｅｓ            9361589    384
#
# [999912 rows x 4 columns]

# %%
agg = book_tags.groupby(['tag_name'])['count'].agg({'sum'}).reset_index()
agg = agg.sort_values(by = 'sum', ascending = False).reset_index(drop = True)
agg.head()
# Out:
#             tag_name        sum
# 0            to-read  140718761
# 1  currently-reading    7507958
# 2          favorites    4503173
# 3            fiction    3688819
# 4            fantasy    3548157

# %%
# 상위 태그 갯수 확인
(ggplot(data = agg.loc[0:20])
 + geom_bar(aes(x = 'tag_name', y = 'sum'), fill = '#49bdb7', stat = "identity")
 + labs(title = "top 20 tag count",
        x = 'tag',
        y = 'tag Count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black', rotation = 60),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (12,6))

)
# Out:
# <ggplot: (125416941984)>

# %%
# 태그가 유사한 책들로 추천이 가능하나, to_read 처럼 압도적으로 갯수가 많은 태그는 제거할 필요 있음
pd.DataFrame(agg['sum'].describe()).T
# Out:
#        count         mean            std  min  25%   50%   75%          max
# sum  34252.0  6097.490716  762709.169868 -1.0  3.0  10.0  52.0  140718761.0

# %% [markdown]
# ### ratings 평점 정보 확인

# %%
ratings
# Out:
#         book_id  user_id  rating
# 0             1      314       5
# 1             1      439       3
# 2             1      588       5
# 3             1     1169       4
# 4             1     1185       4
# ...         ...      ...     ...
# 981751    10000    48386       5
# 981752    10000    49007       4
# 981753    10000    49383       5
# 981754    10000    50124       5
# 981755    10000    51328       1
#
# [981756 rows x 3 columns]

# %%
agg = ratings.groupby(['user_id'])['book_id'].agg({'count'}).reset_index()

# 사용자가 몇 권을 읽었나
(ggplot(data = agg)
 + geom_histogram(aes(x = 'count'),binwidth = 5, fill = '#49bdb7')
 + labs(title = "average number of the read count",
        x = 'read count',
        y = 'user Count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (12,6))

)
# Out:
# <ggplot: (125417349081)>

# %%
pd.DataFrame(agg['count'].describe()).T
# Out:
#          count       mean       std  min  25%  50%   75%    max
# count  53424.0  18.376685  26.26869  2.0  3.0  8.0  22.0  200.0

# %%
agg = ratings.groupby(['book_id'])['book_id'].agg({'count'}).reset_index()

# 책이 몇번 읽혔는가
(ggplot(data = agg)
 + geom_histogram(aes(x = 'count', y = 'stat(count)'),binwidth = 5, fill = '#49bdb7')
 + labs(title = "average read count",
        x = 'read count',
        y = 'binwidth')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (12,6))

)
# Out:
# <ggplot: (125418599665)>

# %%
pd.DataFrame(agg['count'].describe()).T
# Out:
#          count     mean       std  min   25%    50%    75%    max
# count  10000.0  98.1756  5.690167  8.0  99.0  100.0  100.0  100.0

# %%
# 해리포터같은 시리즈물은 이어보게 되지 않을까?
books[books['book_id'].isin([1,2,3,4,5,6,7,8])].head()
# Out:
#     book_id                                  authors  \
# 1         3              J.K. Rowling, Mary GrandPré
# 17        5  J.K. Rowling, Mary GrandPré, Rufus Beck
# 20        2              J.K. Rowling, Mary GrandPré
# 23        6              J.K. Rowling, Mary GrandPré
# 26        1              J.K. Rowling, Mary GrandPré
#
#                                                 title  ratings_count  \
# 1   Harry Potter and the Sorcerer's Stone (Harry P...        4602479
# 17  Harry Potter and the Prisoner of Azkaban (Harr...        1832823
# 20  Harry Potter and the Order of the Phoenix (Har...        1735368
# 23  Harry Potter and the Goblet of Fire (Harry Pot...        1753043
# 26  Harry Potter and the Half-Blood Prince (Harry ...        1678823
#
#     average_rating language_code
# 1             4.44           eng
# 17            4.53           eng
# 20            4.46           eng
# 23            4.53           eng
# 26            4.54           eng

# %%
ratings[(ratings['user_id'] == 314) & (ratings['book_id'].isin([1,2,3,4,5,6,7,8]))]
# Out:
#      book_id  user_id  rating
# 0          1      314       5
# 200        3      314       3
# 400        5      314       4
# 501        6      314       5

# %%
# 다른 유저들도 314번 사용자와 같이 시리즈물은 읽어보지 않을까?

agg = ratings[ratings['book_id'].isin([1,2,3,4,5,6,7,8])].groupby(['user_id'])['book_id'].agg({'nunique'})
agg = agg.reset_index()
agg = agg.groupby(['nunique'])['user_id'].agg({'count'}).reset_index()

(ggplot(data = agg)
 + geom_bar(aes(x = 'nunique', y = 'count'),fill = '#49bdb7', stat = "identity")
 + labs(title = "harry poter's read count",
        x = 'series count',
        y = 'reading person count')
 + theme_light()
     + theme(
         axis_text_x = element_text(color = 'black'),
         axis_text_y = element_text(color = 'black'),
         axis_line = element_line(color = 'black'),
         axis_ticks = element_line(color = 'grey'),
         figure_size = (12,6))

)
# Out:
# <ggplot: (125418633909)>

# %%
# 64%의 사용자는 시리즈물을 같이 읽는 편이다
agg['ratio'] = agg['count'] / agg['count'].sum()
agg[['nunique','ratio']].T
# Out:
#                 0         1         2         3         4         5         6  \
# nunique  1.000000  2.000000  3.000000  4.000000  5.000000  6.000000  7.000000
# ratio    0.362319  0.152174  0.126812  0.112319  0.112319  0.101449  0.028986
#
#                 7
# nunique  8.000000
# ratio    0.003623

# %%
## 기존 데이터를 train, test set으로 분리

agg = ratings.groupby(['user_id'])['book_id'].agg({'unique'}).reset_index()
agg.head()
# Out:
#    user_id                          unique
# 0        1              [1180, 4893, 6285]
# 1        2              [8034, 8855, 9762]
# 2        3                    [9014, 9049]
# 3        4              [3273, 3469, 8464]
# 4        5  [4829, 6646, 6703, 7487, 8072]

# %%
agg['train'] = agg['unique'].apply(lambda x : np.random.choice(x, len(x)//2))
agg.head()
# Out:
#    user_id                          unique         train
# 0        1              [1180, 4893, 6285]        [1180]
# 1        2              [8034, 8855, 9762]        [8855]
# 2        3                    [9014, 9049]        [9049]
# 3        4              [3273, 3469, 8464]        [8464]
# 4        5  [4829, 6646, 6703, 7487, 8072]  [4829, 7487]

# %%
test = []
for i in tqdm(range(0, agg.shape[0])):
    test_rec = list(set(agg.loc[1,'unique']).difference(set(agg.loc[1, 'train'])))
    test.append(test_rec)
agg['test'] = test
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53424.0), HTML(value='')))

# %%
# train_dataset

train_map = agg[['user_id', 'train']]

#unnest tag
train_map_unnest = np.dstack(
    (
        np.repeat(train_map.user_id.values, list(map(len,train_map.train))),
        np.concatenate(train_map.train.values)
    )
)

train_map_unnest = pd.DataFrame(data = train_map_unnest[0], columns = train_map.columns)
train_map_unnest.head()
# Out:
#    user_id  train
# 0        1   1180
# 1        2   8855
# 2        3   9049
# 3        4   8464
# 4        5   4829

# %%
#test dataset
test_map = agg[['user_id', 'test']]

# unnest tags
test_map_unnest = np.dstack(
    (
        np.repeat(test_map.user_id.values, list(map(len, test_map.test))), 
        np.concatenate(test_map.test.values)
    )
)

test_map_unnest = pd.DataFrame(data = test_map_unnest[0], columns = test_map.columns)
test_map_unnest.head()
# Out:
#    user_id  test
# 0        1  8034
# 1        1  9762
# 2        2  8034
# 3        2  9762
# 4        3  8034

# %%
train_map_unnest.columns = ['user_id', 'book_id']
test_map_unnest.columns = ['user_id', 'book_id']
train_map_unnest.to_csv("train.csv", index=False)
test_map_unnest.to_csv("test.csv", index=False)

# %% [markdown]
# ## 추천시스템 적용

# %%
books = pd.read_csv('C:/Users/sbpark/books.csv')
book_tags = pd.read_csv('C:/Users/sbpark/book_tags.csv')
train = pd.read_csv('C:/Users/sbpark/train.csv')
test = pd.read_csv('C:/Users/sbpark/test.csv')
tags = pd.read_csv('C:/Users/sbpark/tags.csv')
to_read = pd.read_csv('C:/Users/sbpark/to_read.csv')

# %%
train['book_id'] = train['book_id'].astype(str)
test['book_id'] = test['book_id'].astype(str)
books['book_id'] = books['book_id'].astype(str)

# %%
sol = test.groupby(['user_id'])['book_id'].agg({'unique'}).reset_index()
gt = {}
for user in tqdm(sol['user_id'].unique()):
    gt[user] = list(sol[sol['user_id'] == user]['unique'].values[0])
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53424.0), HTML(value='')))

# %% [markdown]
# ### 한사람당 200권의 책을 추천한다

# %%
rec_df = pd.DataFrame()
rec_df['user_id'] = train['user_id'].unique()

# %% [markdown]
# #### baseline
# - 통계 기반의 모델

# %%
books.sort_values(by = 'books_count', ascending = False)[0:5]
# Out:
#         id  book_id  best_book_id   work_id  books_count       isbn  \
# 9       10     1885          1885   3060926         3455  679783261
# 1724  1725  6324090       6324090  55548884         3296        NaN
# 70      71    18490         18490   4836639         2618  141439475
# 292    293      295           295   3077988         2573  753453800
# 42      43    10210         10210   2977639         2568  142437204
#
#             isbn13                                            authors  \
# 9     9.780680e+12                                        Jane Austen
# 1724           NaN                        Lewis Carroll, John Tenniel
# 70    9.780141e+12  Mary Wollstonecraft Shelley, Percy Bysshe Shel...
# 292   9.780753e+12                             Robert Louis Stevenson
# 42    9.780142e+12                    Charlotte Brontë, Michael Mason
#
#       original_publication_year                           original_title  ...  \
# 9                        1813.0                      Pride and Prejudice  ...
# 1724                     1865.0                                      NaN  ...
# 70                       1818.0  Frankenstein; or, The Modern Prometheus  ...
# 292                      1882.0                          Treasure Island  ...
# 42                       1847.0                                Jane Eyre  ...
#
#      ratings_count work_ratings_count  work_text_reviews_count  ratings_1  \
# 9          2035490            2191465                    49152      54700
# 1724         30426              85031                     5047       1724
# 70          808589             883563                    19993      29366
# 292         268012             310515                     7917       5349
# 42         1198557            1286135                    31212      35132
#
#       ratings_2  ratings_3  ratings_4  ratings_5  \
# 9         86485     284852     609755    1155673
# 1724       4863      18094      27848      32502
# 70        74142     231022     300495     248538
# 292       19127      86487     114968      84584
# 42        64274     212294     400214     574221
#
#                                               image_url  \
# 9     https://images.gr-assets.com/books/1320399351m...
# 1724  https://images.gr-assets.com/books/1391204048m...
# 70    https://images.gr-assets.com/books/1381512375m...
# 292   https://images.gr-assets.com/books/1485248909m...
# 42    https://images.gr-assets.com/books/1327867269m...
#
#                                         small_image_url
# 9     https://images.gr-assets.com/books/1320399351s...
# 1724  https://images.gr-assets.com/books/1391204048s...
# 70    https://images.gr-assets.com/books/1381512375s...
# 292   https://images.gr-assets.com/books/1485248909s...
# 42    https://images.gr-assets.com/books/1327867269s...
#
# [5 rows x 23 columns]

# %%
# 많이 읽은 책 순서대로 추천할 것이다
porpular_rec_model = books.sort_values(by = 'books_count', ascending = False)['book_id'].values[0:500]

# %%
total_rec_list = {}
for user in tqdm(rec_df['user_id'].unique()):
    rec_list = []
    for rec in porpular_rec_model[0:200]:
        rec_list.append(rec)
    total_rec_list[user] = rec_list
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53382.0), HTML(value='')))

# %%
# 평가 함수 : MAP, NDCG, EntDiv(얼마나 개인화 되었는가? 다양성 지표)
import six
import math

# https://github.com/kakao-arena/brunch-article-recommendation/blob/master/evaluate.py

class evaluate():
    def __init__(self, recs, gt, topn=100):
        self.recs = recs
        self.gt = gt 
        self.topn = topn 
        
    def _ndcg(self):
        Q, S = 0.0, 0.0
        for u, seen in six.iteritems(self.gt):
            seen = list(set(seen))
            rec = self.recs.get(u, [])
            if not rec or len(seen) == 0:
                continue

            dcg = 0.0
            idcg = sum([1.0 / math.log(i + 2, 2) for i in range(min(len(seen), len(rec)))])
            for i, r in enumerate(rec):
                if r not in seen:
                    continue
                rank = i + 1
                dcg += 1.0 / math.log(rank + 1, 2)
            ndcg = dcg / idcg
            S += ndcg
            Q += 1
        return S / Q


    def _map(self):
        n, ap = 0.0, 0.0
        for u, seen in six.iteritems(self.gt):
            seen = list(set(seen))
            rec = self.recs.get(u, [])
            if not rec or len(seen) == 0:
                continue

            _ap, correct = 0.0, 0.0
            for i, r in enumerate(rec):
                if r in seen:
                    correct += 1
                    _ap += (correct / (i + 1.0))
            _ap /= min(len(seen), len(rec))
            ap += _ap
            n += 1.0
        return ap / n


    def _entropy_diversity(self):
        sz = float(len(self.recs)) * self.topn
        freq = {}
        for u, rec in six.iteritems(self.recs):
            for r in rec:
                freq[r] = freq.get(r, 0) + 1
        ent = -sum([v / sz * math.log(v / sz) for v in six.itervalues(freq)])
        return ent
    
    def _evaluate(self):
        print('MAP@%s: %s' % (self.topn, self._map()))
        print('NDCG@%s: %s' % (self.topn, self._ndcg()))
        print('EntDiv@%s: %s' % (self.topn, self._entropy_diversity()))

# %%
#MAP, NDCG 매우 낮음 : 200권을 단순히 많이 읽힌 순으로 추천했기 때문

evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=200)
evaluate_func._evaluate()
# Out:
# MAP@200: 0.0
# NDCG@200: 0.0
# EntDiv@200: 5.298317366548021

# %% [markdown]
# #### Baseline 응용
# - 많이 읽은 글 중 평점이 높은 글을 우선
#
# - *내가 좋아하는 작가의 글을 우선 추천*
#
# - 장바구니에 담긴 글과 작가의 글을 우선 추천
#
# - 읽은 글의 시리즈글이 나오면 추천
#
# - 최신의 글을 추천

# %%
train = pd.merge(train, books[['book_id','authors','ratings_count']], how = 'left', on = 'book_id')

# %%
agg = train.groupby(['user_id','authors'])['authors'].agg({'count'}).reset_index()
agg = agg.sort_values(by = 'count', ascending = False)
agg.head()
# Out:
#        user_id                 authors  count
# 7232     11927             Bill Bryson      6
# 8963     14546             Bill Bryson      6
# 9500     15318             Bill Bryson      5
# 18532    30092  Sophocles, J.E. Thomas      5
# 5837      9771             Bill Bryson      5

# %%
# 작가의 책을 추천하되, 책 중에서도 평점이 높은 것부터 추천한다.
author_books = books[['book_id', 'authors', 'ratings_count']].sort_values(by=['authors', 'ratings_count'], ascending=[True, False])
author_books = author_books.reset_index(drop=True)

author_books.head()
# Out:
#     book_id                        authors  ratings_count
# 0    101911               A. Manette Ansay          23966
# 1  16081754            A. Meredith Walters          24615
# 2  16102880            A. Meredith Walters          24287
# 3     99107  A.A. Milne, Ernest H. Shepard         207550
# 4    776407  A.A. Milne, Ernest H. Shepard          69102

# %%
author_rec_model = agg.merge(author_books, how='left', on=['authors'])

# %%
author_rec_model.head()
# Out:
#    user_id      authors  count  book_id  ratings_count
# 0    11927  Bill Bryson      6     9791         250192
# 1    11927  Bill Bryson      6       21         191535
# 2    11927  Bill Bryson      6       28          66947
# 3    11927  Bill Bryson      6       24          58688
# 4    11927  Bill Bryson      6  7507825          55296

# %%
author_rec_model[author_rec_model['user_id'] == 11927]['book_id'].values
# Out:
# array(['9791', '21', '28', '24', '7507825', '25', '10538', '27', '26',
#        '17262366', '135611', '29', '25489012', '10541', '11', '13',
#        '8695', '8694', '8698', '365', '360', '357', '841628', '359',
#        '249', '250', '291', '32542', '5358', '5359', '32499', '24192',
#        '5349', '5355', '5350', '5351', '5348', '5354', '1110', '5346',
#        '5356', '5360', '17288661', '5352', '3613997', '13573236', '5345',
#        '7933437', '5357', '1248179', '11600163', '20707959', '29354916',
#        '1205297', '25387351', '5347', '13154952', '6398972', '10720733',
#        '452235', '3950967', '13497818', '862041', '10', '30065028',
#        '1317181', '31538647', '2002', '264', '930'], dtype=object)

# %%
total_rec_list = {}
for user in tqdm(rec_df['user_id'].unique()):
    rec_list = []
    author_rec_model_ = author_rec_model[author_rec_model['user_id'] == user]['book_id'].values
    for rec in author_rec_model_: 
        rec_list.append(rec)
    
    # 작가의 책이 200권이 안되면 인기 기반으로 추천
    if len(rec_list) < 200:
        for i in porpular_rec_model[0:200]:
            rec_list.append(rec)
        
    total_rec_list[user] = rec_list[0:200]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53382.0), HTML(value='')))

# %%
#MAP, NDCG 상향되었음 

evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=200)
evaluate_func._evaluate()
# Out:
# MAP@200: 0.129612955961007
# NDCG@200: 0.027795507020042784
# EntDiv@200: 5.86313253263542

# %% [markdown]
# #### 후처리
# - 이미 읽은 책은 추천하면 안됨
#
# - 읽은 언어와 맞는 책을 추천해야 함

# %%
# 내가 읽은 책의 목록을 추출 
read_list = train.groupby(['user_id'])['book_id'].agg({'unique'}).reset_index()
read_list.head()
# Out:
#    user_id        unique
# 0        1        [4893]
# 1        2        [8034]
# 2        3        [9049]
# 3        4        [3273]
# 4        5  [4829, 7487]

# %%
total_rec_list = {}
for user in tqdm(rec_df['user_id'].unique()):
    rec_list = []
    author_rec_model_ = author_rec_model[author_rec_model['user_id'] == user]['book_id'].values
    seen = read_list[read_list['user_id'] == user]['unique'].values[0]
    for rec in author_rec_model_: 
        # 읽지 않은 책에 대해서만 추천한다
        if rec not in seen:
            rec_list.append(rec)
    
    if len(rec_list) < 200:
        for i in porpular_rec_model[0:200]:
            if rec not in seen:
                rec_list.append(rec)

    total_rec_list[user] = rec_list[0:200]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53382.0), HTML(value='')))

# %%
#MAP, NDCG 낮아짐

evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=200)
evaluate_func._evaluate()
# Out:
# MAP@200: 0.09472368898383651
# NDCG@200: 0.020222180147627517
# EntDiv@200: 5.104552007613972

# %% [markdown]
# ### SGD 협업필터링

# %%
class MatrixFactorization():
    def __init__(self, R, k, learning_rate, reg_param, epochs, verbose=False):
        """
        :param R: rating matrix
        :param k: latent parameter
        :param learning_rate: alpha on weight update
        :param reg_param: beta on weight update
        :param epochs: training epochs
        :param verbose: print status
        """
        self._R = R
        self._num_users, self._num_items = R.shape
        self._k = k
        self._learning_rate = learning_rate
        self._reg_param = reg_param
        self._epochs = epochs
        self._verbose = verbose


    def fit(self):
        """
        training Matrix Factorization : Update matrix latent weight and bias

        참고: self._b에 대한 설명
        - global bias: input R에서 평가가 매겨진 rating의 평균값을 global bias로 사용
        - 정규화 기능. 최종 rating에 음수가 들어가는 것 대신 latent feature에 음수가 포함되도록 해줌.

        :return: training_process
        """

        # init latent features
        self._P = np.random.normal(size=(self._num_users, self._k))
        self._Q = np.random.normal(size=(self._num_items, self._k))

        # init biases
        self._b_P = np.zeros(self._num_users)
        self._b_Q = np.zeros(self._num_items)
        self._b = np.mean(self._R[np.where(self._R != 0)])

        # train while epochs
        self._training_process = []
        for epoch in range(self._epochs):
            # rating이 존재하는 index를 기준으로 training
            xi, yi = self._R.nonzero()
            for i, j in zip(xi, yi):
                self.gradient_descent(i, j, self._R[i, j])
            cost = self.cost()
            self._training_process.append((epoch, cost))

            # print status
            if self._verbose == True and ((epoch + 1) % 10 == 0):
                print("Iteration: %d ; cost = %.4f" % (epoch + 1, cost))


    def cost(self):
        """
        compute root mean square error
        :return: rmse cost
        """

        # xi, yi: R[xi, yi]는 nonzero인 value를 의미한다.
        # 참고: http://codepractice.tistory.com/90
        xi, yi = self._R.nonzero()
        # predicted = self.get_complete_matrix()
        cost = 0
        for x, y in zip(xi, yi):
            cost += pow(self._R[x, y] - self.get_prediction(x, y), 2)
        return np.sqrt(cost/len(xi))


    def gradient(self, error, i, j):
        """
        gradient of latent feature for GD

        :param error: rating - prediction error
        :param i: user index
        :param j: item index
        :return: gradient of latent feature tuple
        """

        dp = (error * self._Q[j, :]) - (self._reg_param * self._P[i, :])
        dq = (error * self._P[i, :]) - (self._reg_param * self._Q[j, :])
        return dp, dq


    def gradient_descent(self, i, j, rating):
        """
        graident descent function

        :param i: user index of matrix
        :param j: item index of matrix
        :param rating: rating of (i,j)
        """

        # get error
        prediction = self.get_prediction(i, j)
        error = rating - prediction

        # update biases
        self._b_P[i] += self._learning_rate * (error - self._reg_param * self._b_P[i])
        self._b_Q[j] += self._learning_rate * (error - self._reg_param * self._b_Q[j])

        # update latent feature
        dp, dq = self.gradient(error, i, j)
        self._P[i, :] += self._learning_rate * dp
        self._Q[j, :] += self._learning_rate * dq


    def get_prediction(self, i, j):
        """
        get predicted rating: user_i, item_j
        :return: prediction of r_ij
        """
        return self._b + self._b_P[i] + self._b_Q[j] + self._P[i, :].dot(self._Q[j, :].T)


    def get_complete_matrix(self):
        """
        computer complete matrix PXQ + P.bias + Q.bias + global bias

        - PXQ 행렬에 b_P[:, np.newaxis]를 더하는 것은 각 열마다 bias를 더해주는 것
        - b_Q[np.newaxis:, ]를 더하는 것은 각 행마다 bias를 더해주는 것
        - b를 더하는 것은 각 element마다 bias를 더해주는 것

        - newaxis: 차원을 추가해줌. 1차원인 Latent들로 2차원의 R에 행/열 단위 연산을 해주기위해 차원을 추가하는 것.

        :return: complete matrix R^
        """
        return self._b + self._b_P[:, np.newaxis] + self._b_Q[np.newaxis:, ] + self._P.dot(self._Q.T)

# %%
# 책, 유저 아이디 매핑
user2idx = {}
for i, l in enumerate(train['user_id'].unique()):
    user2idx[l] = i
    
book2idx = {}
for i, l in enumerate(train['book_id'].unique()):
    book2idx[l] = i

# %%
idx2user = {i: user for user, i in user2idx.items()}
idx2book = {i: item for item, i in book2idx.items()}

# %%
data = train[['user_id', 'book_id']].reset_index(drop=True)
useridx = data['useridx'] = train['user_id'].apply(lambda x: user2idx[x]).values
bookidx = data['bookidx'] = train['book_id'].apply(lambda x: book2idx[x]).values
rating = np.ones(len(data))

# %%
# 매트릭스 생성
import scipy 

purchase_sparse = scipy.sparse.csr_matrix((rating, (useridx, bookidx)), shape=(len(set(useridx)), len(set(bookidx))))
purchase_sparse
# Out:
# <53382x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 386732 stored elements in Compressed Sparse Row format>

# %%
# 매트릭스 > 넘파이
R = purchase_sparse.toarray()

# %%
# %%time
factorizer = MatrixFactorization(R, k=20, learning_rate=0.01, reg_param=0.01, epochs=100, verbose=True)
factorizer.fit()
# Out:
# Iteration: 10 ; cost = 0.4634
# Iteration: 20 ; cost = 0.3143
# Iteration: 30 ; cost = 0.2602
# Iteration: 40 ; cost = 0.2305
# Iteration: 50 ; cost = 0.2105
# Iteration: 60 ; cost = 0.1954
# Iteration: 70 ; cost = 0.1832
# Iteration: 80 ; cost = 0.1730
# Iteration: 90 ; cost = 0.1642
# Iteration: 100 ; cost = 0.1566
# Wall time: 24min 39s

# %%
del R; gc.collect() 
sgd_rec_model = factorizer.get_complete_matrix()

# %%
# 내가 읽은 책의 목록을 추출 
read_list = train.groupby(['user_id'])['book_id'].agg({'unique'}).reset_index()
read_list.head()
# Out:
#    user_id        unique
# 0        1        [4893]
# 1        2        [8034]
# 2        3        [9049]
# 3        4        [3273]
# 4        5  [4829, 7487]

# %%
total_rec_list = {}
for user in tqdm(data['useridx'].unique()):
    rec_list = []
    
    # 기존에 만든 Book ID를 변경 
    rating_scores = [(idx2book[i], c) for i, c in enumerate(sgd_rec_model[user]) if i != user] # 자기 자신이 추천안되도록 
    rating_scores = sorted(rating_scores, key = lambda x: x[1], reverse=True) # 평점이 높은 순서대로 정렬 
    
    seen = read_list[read_list['user_id'] == idx2user[user]]['unique'].values[0]
    for rec in rating_scores[0:250]: 
        if rec[0] not in seen:
            rec_list.append(rec[0])
    
    if len(rec_list) < 200:
        for i in popular_rec_model[0:200]:
            if rec not in seen:
                rec_list.append(rec)

    total_rec_list[idx2user[user]] = rec_list[0:200]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53382.0), HTML(value='')))

# %%
evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=200)
evaluate_func._evaluate()
# Out:
# MAP@200: 0.002076141164098073
# NDCG@200: 0.015471526046575645
# EntDiv@200: 8.308759143805876

# %% [markdown]
# ### ALS 방식을 이용한 협업필터링

# %%
from implicit.evaluation import  *
from implicit.als import AlternatingLeastSquares as ALS
from implicit.bpr import BayesianPersonalizedRanking as BPR

# factors는 20이 적당
als_model = ALS(factors=20, regularization=0.01, iterations = 100)
als_model.fit(purchase_sparse.T)
# Out:
# WARNING:root:Intel MKL BLAS detected. Its highly recommend to set the environment variable 'export MKL_NUM_THREADS=1' to disable its internal multithreading
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))

# %%
als_model.recommend(0, purchase_sparse, N=200)[0:10]
# Out:
# [(1739, 0.00047619952),
#  (9502, 0.00047308288),
#  (164, 0.00044972065),
#  (5730, 0.0004463465),
#  (5140, 0.00043478142),
#  (8043, 0.00041931495),
#  (7853, 0.00040431158),
#  (8828, 0.00040042156),
#  (5813, 0.00039952292),
#  (6642, 0.00037361257)]

# %%
total_rec_list = {}
for user in tqdm(data['useridx'].unique()):
    rec_list = []
    
    # 기존에 만든 Book ID를 변경 
    seen = read_list[read_list['user_id'] == idx2user[user]]['unique'].values[0]
    recs = als_model.recommend(user, purchase_sparse, N=250)
    recs = [idx2book[x[0]] for x in recs][0:250]  
    
    for rec in recs: 
        if rec not in seen:
            rec_list.append(rec)
    
    if len(rec_list) < 200:
        for i in popular_rec_model[0:200]:
            if rec not in seen:
                rec_list.append(rec)

    total_rec_list[idx2user[user]] = rec_list[0:200]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53382.0), HTML(value='')))

# %%
evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=200)
evaluate_func._evaluate()
# Out:
# MAP@200: 0.0
# NDCG@200: 0.0
# EntDiv@200: 7.90860247664465

# %% [markdown]
# ### 컨텐츠 기반의 모델 TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(books['title'])
print(tfidf_matrix.shape)
# Out:
# (10000, 9019)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)
cosine_matrix.shape
# Out:
# (10000, 10000)

# %%
# book title와 id를 매핑할 dictionary를 생성해줍니다. 
book2id = {}
for i, c in enumerate(books['title']): book2id[i] = c

# id와 book title를 매핑할 dictionary를 생성해줍니다. 
id2book = {}
for i, c in book2id.items(): id2book[c] = i
    
# book_id와 title를 매핑할 dictionary를 생성해줍니다.
bookid2book = {}
for i, j in zip(books['title'].values, books['book_id'].values):
    bookid2book[i] = j

# %%
books['title'].head()
# Out:
# 0              The Hunger Games (The Hunger Games, #1)
# 1    Harry Potter and the Sorcerer's Stone (Harry P...
# 2                              Twilight (Twilight, #1)
# 3                                To Kill a Mockingbird
# 4                                     The Great Gatsby
# Name: title, dtype: object

# %%
idx = id2book['Twilight (Twilight, #1)']  
sim_scores = [(book2id[i], c) for i, c in enumerate(cosine_matrix[idx]) if i != idx] 
sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse=True)
sim_scores[0:10]
# Out:
# [('The Twilight Saga (Twilight, #1-4)', 0.920347418277986),
#  ('The Twilight Collection (Twilight, #1-3)', 0.8786339079447184),
#  ('The Twilight Saga Complete Collection  (Twilight, #1-4 + 3.5)',
#   0.7697532056304309),
#  ('Twilight and History', 0.7465001575650626),
#  ('The Twilight Saga: The Official Illustrated Guide (Twilight, #4.5)',
#   0.7045174300631831),
#  ('Twilight Eyes', 0.6770737331426326),
#  ('Twilight (The Mediator, #6)', 0.6377631333498953),
#  ('New Moon (Twilight, #2)', 0.6185575138625542),
#  ('Eclipse (Twilight, #3)', 0.612819563854136),
#  ('The Servants of Twilight', 0.5837817298466093)]

# %%
train = pd.merge(train, books[['book_id', 'title']], how='left', on='book_id')
train.head()
# Out:
#    user_id book_id        authors  ratings_count     title
# 0        1    4893            NaN            NaN       NaN
# 1        2    8034            NaN            NaN       NaN
# 2        3    9049            NaN            NaN       NaN
# 3        4    3273  Alan Brennert        75307.0  Moloka'i
# 4        5    4829            NaN            NaN       NaN

# %%
# 0. 학습셋에서 제목이 있는 경우에 대해서만 진행
tf_train = train[train['title'].notnull()].reset_index(drop=True)
tf_train['idx2title'] = tf_train['title'].apply(lambda x: id2book[x])
tf_train.head()
# Out:
#    user_id book_id                                            authors  \
# 0        4    3273                                      Alan Brennert
# 1        7    4138                                      David Sedaris
# 2        7    1519  Aeschylus, Robert Fagles, William Bedell Stanford
# 3        7    1519  Aeschylus, Robert Fagles, William Bedell Stanford
# 4       10    5907                                     J.R.R. Tolkien
#
#    ratings_count                           title  idx2title
# 0        75307.0                        Moloka'i       1215
# 1       201337.0                           Naked        343
# 2        24588.0  The Oresteia  (Ορέστεια, #1-3)       4148
# 3        24588.0  The Oresteia  (Ορέστεια, #1-3)       4148
# 4      2071616.0                      The Hobbit          6

# %%
idx2title2book = {}
for i, j in zip(tf_train['idx2title'].values, tf_train['book_id'].values):
    idx2title2book[i] = j

# %%
# 1. 각 유저별로 읽은 책의 목록을 수집 
user = 7
read_list = tf_train.groupby(['user_id'])['idx2title'].agg({'unique'}).reset_index()
seen = read_list[read_list['user_id'] == user]['unique'].values[0]
seen
# Out:
# array([ 343, 4148], dtype=int64)

# %%
# 2. 읽은 책과 유사한 책 추출 
## 343번째 책과 다른 책들간의 유사도 
cosine_matrix[343]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# 3. 읽은 책과 유사한 책 추출 
total_cosine_sim = np.zeros(len(book2id))
for book_ in seen: 
    # 3. 모든 책에 대해서 유사도를 더한 값을 계산 
    # 343번째 책과 248의 유사도가 모두 결합된 유사도
    total_cosine_sim += cosine_matrix[book_]

# %%
# 4. 3에서 유사도가 가장 높은 순서대로 추출
sim_scores = [(i, c) for i, c in enumerate(total_cosine_sim) if i not in seen] # 자기 자신을 제외한 영화들의 유사도 및 인덱스를 추출 
sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse=True) # 유사도가 높은 순서대로 정렬 
sim_scores[0:5]
# Out:
# [(4809, 0.793036327171204),
#  (6199, 0.6915730356677104),
#  (3194, 0.6607508855409738),
#  (1570, 0.6390974315343301),
#  (7393, 0.5820260477746269)]

# %%
book2id[4809]
# Out:
# 'The Naked and the Dead'

# %%
bookid2book[book2id[4809]]
# Out:
# '12467'

# %%
tf_train['user_id'].unique()
# Out:
# array([    4,     7,    10, ..., 53416, 53420, 53424], dtype=int64)

# %%
tf_train.head()
# Out:
#    user_id book_id                                            authors  \
# 0        4    3273                                      Alan Brennert
# 1        7    4138                                      David Sedaris
# 2        7    1519  Aeschylus, Robert Fagles, William Bedell Stanford
# 3        7    1519  Aeschylus, Robert Fagles, William Bedell Stanford
# 4       10    5907                                     J.R.R. Tolkien
#
#    ratings_count                           title  idx2title
# 0        75307.0                        Moloka'i       1215
# 1       201337.0                           Naked        343
# 2        24588.0  The Oresteia  (Ορέστεια, #1-3)       4148
# 3        24588.0  The Oresteia  (Ορέστεια, #1-3)       4148
# 4      2071616.0                      The Hobbit          6

# %%
## 전체 영화에 대해서 진행 
total_rec_list = {}

read_list1 = train.groupby(['user_id'])['book_id'].agg({'unique'}).reset_index()
read_list2 = tf_train.groupby(['user_id'])['idx2title'].agg({'unique'}).reset_index()

for user in tqdm(train['user_id'].unique()):
    rec_list = []
        
    # 만약 TF-IDF 소속의 추천대상이라면 Contents 기반의 추천 
    if user in tf_train['user_id'].unique():
        # 1. 각 유저별로 읽은 책의 목록을 수집 
        seen = read_list2[read_list2['user_id'] == user]['unique'].values[0]
        # 2. 읽은 책과 유사한 책 추출 
        total_cosine_sim = np.zeros(len(book2id))
        for book_ in seen: 
            # 3. 모든 책에 대해서 유사도를 더한 값을 계산 
            # 343번째 책과 248의 유사도가 모두 결합된 유사도
            total_cosine_sim += cosine_matrix[book_]
            
        # 4. 3에서 유사도가 가장 높은 순서대로 추출
        sim_scores = [(bookid2book[book2id[i]], c) for i, c in enumerate(total_cosine_sim) if i not in seen] # 자기 자신을 제외한 영화들의 유사도 및 인덱스를 추출 
        recs = sorted(sim_scores, key = lambda x: x[1], reverse=True)[0:300] # 유사도가 높은 순서대로 정렬 
        for rec in recs: 
            if rec not in seen:
                rec_list.append(rec)   
        
    # 그렇지 않으면 인기도 기반의 추천 
    else: 
        seen = read_list1[read_list1['user_id'] == user]['unique'].values[0]
        for rec in porpular_rec_model[0:400]:
            if rec not in seen:
                rec_list.append(rec)
                
    total_rec_list[user] = rec_list[0:200]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53382.0), HTML(value='')))
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# ...
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# <ipython-input-98-13d37ab8d84e>:25: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=200)
evaluate_func._evaluate()
# Out:
# MAP@200: 0.0
# NDCG@200: 0.0
# EntDiv@200: 6.909065187843772

# %% [markdown]
# ### 컨텐츠 기반의 모델 WORD2VEC

# %%
agg = train.groupby(['user_id'])['book_id'].agg({'unique'})
agg.head()
# Out:
#                unique
# user_id
# 1              [4893]
# 2              [8034]
# 3              [9049]
# 4              [3273]
# 5        [4829, 7487]

# %%
# int형식은 Word2vec에서 학습이 안되어서 String으로 변경해줍니다. 
sentence = []
for user_sentence in agg['unique'].values:
    sentence.append(list(map(str, user_sentence)))

# %%
# Word2vec의 학습을 진행해줍니다. 
from gensim.models import Word2Vec
embedding_model = Word2Vec(sentence, vector_size=20, window = 5, 
                           min_count=1, workers=4, epochs=200, sg=1)

# %%
embedding_model.wv.most_similar(positive=['4893'], topn=10)
# Out:
# [('9280', 0.8653251528739929),
#  ('7396', 0.8546556234359741),
#  ('4723', 0.842179536819458),
#  ('8121', 0.8392395377159119),
#  ('8382', 0.8237717151641846),
#  ('9620', 0.8104682564735413),
#  ('3898', 0.7976555228233337),
#  ('7205', 0.7951140999794006),
#  ('4906', 0.7806362509727478),
#  ('9834', 0.7764769196510315)]

# %%
## 전체 영화에 대해서 진행 
total_rec_list = {}

read_list = train.groupby(['user_id'])['book_id'].agg({'unique'}).reset_index()
for user in tqdm(train['user_id'].unique()):
    rec_list = []     
    seen = read_list1[read_list1['user_id'] == user]['unique'].values[0]
    word2vec_dict = {}
    for book in seen: 
        for i in embedding_model.wv.most_similar(positive=[book], topn=300):
            if i[0] not in seen: 
                if i[0] not in word2vec_dict.keys(): 
                    word2vec_dict[i[0]] = i[1]
                else:
                    word2vec_dict[i[0]] += i[1]
                
    rec_list = list(dict(sorted(word2vec_dict.items(), key = lambda x: x[1], reverse=True)).keys())
    total_rec_list[user] = rec_list[0:200]
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=53382.0), HTML(value='')))

# %%
evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=200)
evaluate_func._evaluate()
# Out:
# MAP@200: 0.0011069238063688433
# NDCG@200: 0.007536201070641992
# EntDiv@200: 8.899542466883736
